# %%
import os 
import cv2

# %%
import cv2
import os

# Input and output folders
input_folder = r"D:\video_data_js\jm038"
output_folder = input_folder + "_compressed_fiji"
os.makedirs(output_folder, exist_ok=True)

scale_factor = 0.7  # downscale to 70% of original size

# Loop through all AVI files
for filename in os.listdir(input_folder):
    if filename.lower().endswith(".avi"):
        input_path = os.path.join(input_folder, filename)
        output_filename = os.path.splitext(filename)[0] + "_compressed.avi"
        output_path = os.path.join(output_folder, output_filename)

        print(f"Compressing: {filename} ...")

        cap = cv2.VideoCapture(input_path)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH) * scale_factor)
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT) * scale_factor)
        fps = cap.get(cv2.CAP_PROP_FPS)

        # MJPG codec (Fiji compatible)
        fourcc = cv2.VideoWriter_fourcc(*'MJPG')
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

        while True:
            ret, frame = cap.read()
            if not ret:
                break
            frame_resized = cv2.resize(frame, (width, height))
            out.write(frame_resized)

        cap.release()
        out.release()
        print(f"Saved: {output_path}")

print("\n✅ All videos compressed successfully and Fiji-compatible!")
# Out:
# Compressing: 2024-04-30_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-04-30_a_compressed.avi
# Compressing: 2024-05-01_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-05-01_a_compressed.avi
# Compressing: 2024-05-02_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-05-02_a_compressed.avi
# Compressing: 2024-05-03_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-05-03_a_compressed.avi
# Compressing: 2024-05-04_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-05-04_a_compressed.avi
# Compressing: 2024-05-05_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-05-05_a_compressed.avi
# Compressing: 2024-05-06_a.avi ...
# Saved: D:\video_data_js\jm038_compressed_fiji\2024-05-06_a_compressed.avi
#
# ✅ All videos compressed successfully and Fiji-compatible!
